# %%
nama = 'Thomas'
nama_lengkap = "Thomas Marcellino"
batch = 50
_constant = 3.14
alpha = 0.01
st0p_pr0cess = False

# %%
nilai = 90
type(nilai)
# Out:
# int

# %%
suhu = 37
type(suhu)

# %%
tinggi_badan = 175
type(tinggi_badan)
# Out:
# int

# %%
berat_badan = 70
type(berat_badan)
# Out:
# int

# %%
label = 1
type(label)
# Out:
# int

# %%
nama = "Thomas Marcellino"
usia = 22
bmi = 24
timnas = t
